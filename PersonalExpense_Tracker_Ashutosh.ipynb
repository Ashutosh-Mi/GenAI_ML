# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutosh-Mi/GenAI_ML/blob/main/PersonalExpense_Tracker_Ashutosh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

expenses = []
budget = 0.0
expense_file = "expenses.csv"

#Add a new expense
def add_expense():
    date = input("Enter date (YYYY-MM-DD): ")
    category = input("Enter category (e.g., Food, Travel): ")
    try:
        amount = float(input("Enter amount: "))
    except ValueError:
        print("Invalid amount. Expense not added.")
        return
    description = input("Enter description: ")

    expense = {
        'date': date,
        'category': category,
        'amount': amount,
        'description': description
    }
    expenses.append(expense)
    print("Expense added.")

#View all expenses
def view_expenses():
    if not expenses:
        print("No expenses recorded.")
        return

    print("\n--- Expenses ---")
    for i, exp in enumerate(expenses, 1):
        if all(k in exp for k in ('date', 'category', 'amount', 'description')):
            print(f"{i}. {exp['date']} | {exp['category']} | ${exp['amount']:.2f} | {exp['description']}")
        else:
            print(f"{i}. Incomplete expense entry. Skipping.")
    print()

#Set and track the budget
def track_budget():
    global budget
    if budget == 0:
        try:
            budget = float(input("Enter your monthly budget: "))
        except ValueError:
            print("Invalid budget input.")
            return

    total_expenses = sum(exp['amount'] for exp in expenses)
    print(f"\nTotal Expenses: ${total_expenses:.2f}")
    print(f"Monthly Budget: ${budget:.2f}")

    if total_expenses > budget:
        print("You have exceeded your budget!")
    else:
        print(f"You have ${budget - total_expenses:.2f} remaining for the month.\n")

#Load expenses from CSV at start
def load_expenses():
    global expenses
    if os.path.exists(expense_file):
        with open(expense_file, mode='r', newline='') as file:
            reader = csv.DictReader(file)
            for row in reader:
                try:
                    expenses.append({
                        'date': row['date'],
                        'category': row['category'],
                        'amount': float(row['amount']),
                        'description': row['description']
                    })
                except (ValueError, KeyError):
                    print("Error loading an expense entry. Skipping.")

#Save expenses to CSV
def save_expenses():
    with open(expense_file, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['date', 'category', 'amount', 'description'])
        writer.writeheader()
        for exp in expenses:
            writer.writerow(exp)
    print("Expenses saved successfully.")

#Display interactive menu
def display_menu():
    while True:
        print("\n--- Personal Expense Tracker Menu ---")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Track Budget")
        print("4. Save Expenses")
        print("5. Exit")

        choice = input("Choose an option (1-5): ")

        if choice == '1':
            add_expense()
        elif choice == '2':
            view_expenses()
        elif choice == '3':
            track_budget()
        elif choice == '4':
            save_expenses()
        elif choice == '5':
            save_expenses()
            print("Exiting... Goodbye!")
            break
        else:
            print("Invalid option. Please choose between 1 and 5.")

#Main
if __name__ == "__main__":
    load_expenses()
    display_menu()
# Out:
# --- Personal Expense Tracker Menu ---
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1-5):  1
# Enter date (YYYY-MM-DD):  2025-05-30
# Enter category (e.g., Food, Travel):  laptop
# Enter amount:  20000
# Enter description:  for office work
# Expense added.
#
# --- Personal Expense Tracker Menu ---
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1-5):  2
# --- Expenses ---
# 1. 2025-05-29 | Food | $500.00 | Lunch
# 2. 2025-05-30 | Travel | $5000.00 | Travelling
# 3. 2025-05-30 | laptop | $20000.00 | for office work
#
#
# --- Personal Expense Tracker Menu ---
# 1. Add Expense
# 2. View Expenses
# 3. Track Budget
# 4. Save Expenses
# 5. Exit
# Choose an option (1-5):  3
# Enter your monthly budget:  25000
# Total Expenses: $25500.00
# Monthly Budget: $25000.00
# You have exceeded your budget!
#
# --- Personal Expense Tracker Menu ---
# 1. Add Expense
# 2. View Expenses
# ...

# %%
1
